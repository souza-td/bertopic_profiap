# %% [markdown]
# # Explorando as métricas
#
# - Será considerado o arquivo dos experimentos para o qual já foram filtrados os modelos com mais de cinco tópicos 'runs_catalog_filtered.csv'.
# - Serão verificadas as três métricas de coerência de tópicos (c_v, c_npmi, u_mass) buscando filtrar os resultados nos primeiros quartis de cada métrica para avaliação visual.
# - Serão priorizadas modelagens com maior granularidade, consequentemente, maior número de tópicos, quando tal fator não resultar em perda de qualidade das representações e vizualizações geradas.

# %%
import pandas as pd

# %%
df = pd.read_csv('../models/expr_bertopic_profiap/runs_catalog_filtered.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   embedding_model  22 non-null     object
#  1   n_neighbors      22 non-null     int64
#  2   cluster_size     22 non-null     int64
#  3   n_topics         22 non-null     int64
#  4   c_v              22 non-null     float64
#  5   c_npmi           22 non-null     float64
#  6   u_mass           22 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 1.3+ KB

# %%
df.sort_values('n_topics',ascending=False).style.background_gradient(cmap='gray',subset=['n_topics','c_v', 'c_npmi', 'u_mass'])
# Out:
# <style type="text/css">
# #T_31e98_row0_col3, #T_31e98_row15_col4, #T_31e98_row16_col5, #T_31e98_row16_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_31e98_row0_col4 {
#   background-color: #3e3e3e;
#   color: #f1f1f1;
# }
# #T_31e98_row0_col5 {
#   background-color: #888888;
#   color: #f1f1f1;
# }
# #T_31e98_row0_col6 {
#   background-color: #373737;
#   color: #f1f1f1;
# }
# #T_31e98_row1_col3 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_31e98_row1_col4, #T_31e98_row14_col3 {
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_31e98_row1_col5 {
#   background-color: #585858;
#   color: #f1f1f1;
# }
# #T_31e98_row1_col6 {
#   background-color: #0c0c0c;
#   color: #f1f1f1;
# }
# #T_31e98_row2_col3, #T_31e98_row3_col3 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_31e98_row2_col4 {
#   background-color: #1d1d1d;
#   color: #f1f1f1;
# }
# #T_31e98_row2_col5 {
#   background-color: #5a5a5a;
#   color: #f1f1f1;
# }
# #T_31e98_row2_col6 {
#   background-color: #171717;
#   color: #f1f1f1;
# }
# #T_31e98_row3_col4 {
#   background-color: #232323;
#   color: #f1f1f1;
# }
# #T_31e98_row3_col5 {
#   background-color: #444444;
#   color: #f1f1f1;
# }
# #T_31e98_row3_col6, #T_31e98_row4_col4, #T_31e98_row19_col3, #T_31e98_row19_col5, #T_31e98_row20_col3, #T_31e98_row20_col4, #T_31e98_row21_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_31e98_row4_col3 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_31e98_row4_col5 {
#   background-color: #4f4f4f;
#   color: #f1f1f1;
# }
# #T_31e98_row4_col6 {
#   background-color: #2d2d2d;
#   color: #f1f1f1;
# }
# #T_31e98_row5_col3, #T_31e98_row6_col3 {
#   background-color: #d8d8d8;
#   color: #000000;
# }
# #T_31e98_row5_col4 {
#   background-color: #454545;
#   color: #f1f1f1;
# }
# #T_31e98_row5_col5 {
#   background-color: #8e8e8e;
#   color: #f1f1f1;
# }
# #T_31e98_row5_col6 {
#   background-color: #272727;
#   color: #f1f1f1;
# }
# #T_31e98_row6_col4, #T_31e98_row14_col4 {
#   background-color: #4c4c4c;
#   color: #f1f1f1;
# }
# #T_31e98_row6_col5 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_31e98_row6_col6 {
#   background-color: #333333;
#   color: #f1f1f1;
# }
# #T_31e98_row7_col3 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_31e98_row7_col4 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_31e98_row7_col5 {
#   background-color: #b6b6b6;
#   color: #000000;
# }
# #T_31e98_row7_col6 {
#   background-color: #5d5d5d;
#   color: #f1f1f1;
# }
# #T_31e98_row8_col3, #T_31e98_row14_col5 {
#   background-color: #6c6c6c;
#   color: #f1f1f1;
# }
# #T_31e98_row8_col4 {
#   background-color: #969696;
#   color: #f1f1f1;
# }
# #T_31e98_row8_col5, #T_31e98_row12_col4 {
#   background-color: #a2a2a2;
#   color: #f1f1f1;
# }
# #T_31e98_row8_col6 {
#   background-color: #6e6e6e;
#   color: #f1f1f1;
# }
# #T_31e98_row9_col3 {
#   background-color: #565656;
#   color: #f1f1f1;
# }
# #T_31e98_row9_col4 {
#   background-color: #a9a9a9;
#   color: #f1f1f1;
# }
# #T_31e98_row9_col5, #T_31e98_row13_col4 {
#   background-color: #a5a5a5;
#   color: #f1f1f1;
# }
# #T_31e98_row9_col6, #T_31e98_row10_col5 {
#   background-color: #7d7d7d;
#   color: #f1f1f1;
# }
# #T_31e98_row10_col3, #T_31e98_row11_col3, #T_31e98_row12_col3 {
#   background-color: #525252;
#   color: #f1f1f1;
# }
# #T_31e98_row10_col4 {
#   background-color: #5c5c5c;
#   color: #f1f1f1;
# }
# #T_31e98_row10_col6, #T_31e98_row14_col6 {
#   background-color: #717171;
#   color: #f1f1f1;
# }
# #T_31e98_row11_col4 {
#   background-color: #d2d2d2;
#   color: #000000;
# }
# #T_31e98_row11_col5 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_31e98_row11_col6, #T_31e98_row21_col4 {
#   background-color: #989898;
#   color: #f1f1f1;
# }
# #T_31e98_row12_col5 {
#   background-color: #c8c8c8;
#   color: #000000;
# }
# #T_31e98_row12_col6 {
#   background-color: #838383;
#   color: #f1f1f1;
# }
# #T_31e98_row13_col3 {
#   background-color: #222222;
#   color: #f1f1f1;
# }
# #T_31e98_row13_col5 {
#   background-color: #b4b4b4;
#   color: #000000;
# }
# #T_31e98_row13_col6, #T_31e98_row17_col5 {
#   background-color: #ababab;
#   color: #f1f1f1;
# }
# #T_31e98_row15_col3 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_31e98_row15_col5, #T_31e98_row18_col6 {
#   background-color: #cdcdcd;
#   color: #000000;
# }
# #T_31e98_row15_col6 {
#   background-color: #818181;
#   color: #f1f1f1;
# }
# #T_31e98_row16_col3 {
#   background-color: #111111;
#   color: #f1f1f1;
# }
# #T_31e98_row16_col4 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_31e98_row17_col3, #T_31e98_row18_col3 {
#   background-color: #040404;
#   color: #f1f1f1;
# }
# #T_31e98_row17_col4 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_31e98_row17_col6 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_31e98_row18_col4 {
#   background-color: #a3a3a3;
#   color: #f1f1f1;
# }
# #T_31e98_row18_col5 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_31e98_row19_col4 {
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_31e98_row19_col6 {
#   background-color: #898989;
#   color: #f1f1f1;
# }
# #T_31e98_row20_col5 {
#   background-color: #080808;
#   color: #f1f1f1;
# }
# #T_31e98_row20_col6 {
#   background-color: #1c1c1c;
#   color: #f1f1f1;
# }
# #T_31e98_row21_col5 {
#   background-color: #6b6b6b;
#   color: #f1f1f1;
# }
# #T_31e98_row21_col6 {
#   background-color: #616161;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31e98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31e98_level0_col0" class="col_heading level0 col0" >embedding_model</th>
#       <th id="T_31e98_level0_col1" class="col_heading level0 col1" >n_neighbors</th>
#       <th id="T_31e98_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#       <th id="T_31e98_level0_col3" class="col_heading level0 col3" >n_topics</th>
#       <th id="T_31e98_level0_col4" class="col_heading level0 col4" >c_v</th>
#       <th id="T_31e98_level0_col5" class="col_heading level0 col5" >c_npmi</th>
#       <th id="T_31e98_level0_col6" class="col_heading level0 col6" >u_mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31e98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31e98_row0_col0" class="data row0 col0" >granite</td>
#       <td id="T_31e98_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_31e98_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_31e98_row0_col3" class="data row0 col3" >64</td>
#       <td id="T_31e98_row0_col4" class="data row0 col4" >0.477648</td>
#       <td id="T_31e98_row0_col5" class="data row0 col5" >-0.023182</td>
#       <td id="T_31e98_row0_col6" class="data row0 col6" >-5.881825</td>
#     </tr>
#     <tr>
#       <th id="T_31e98_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_31e98_row1_col0" class="data row1 col0" >paraphrase</td>
#       <td id="T_31e98_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_31e98_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_31e98_row1_col3" class="data row1 col3" >62</td>
#       <td id="T_31e98_row1_col4" class="data row1 col4" >0.454723</td>
#       <td id="T_31e98_row1_col5" class="data row1 col5" >-0.052465</td>
#       <td id="T_31e98_row1_col6" class="data row1 col6" >-6.651421</td>
#     </tr>
#     <tr>
#       <th id="T_31e98_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_31e98_row2_col0" class="data row2 col0" >paraphrase</td>
#       <td id="T_31e98_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_31e98_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_31e98_row2_col3" class="data row2 col3" >61</td>
#       <td id="T_31e98_row2_col4" class="data row2 col4" >0.456171</td>
#       <td id="T_31e98_row2_col5" class="data row2 col5" >-0.051186</td>
#       <td id="T_31e98_row2_col6" class="data row2 col6" >-6.444358</td>
#     </tr>
#     <tr>
#       <th id="T_31e98_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_31e98_row3_col0" class="data row3 col0" >paraphrase</td>
#       <td id="T_31e98_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_31e98_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_31e98_row3_col3" class="data row3 col3" >61</td>
#       <td id="T_31e98_row3_col4" class="data row3 col4" >0.460548</td>
#       <td id="T_31e98_row3_col5" class="data row3 col5" >-0.064639</td>
#       <td id="T_31e98_row3_col6" class="data

# %% [markdown]
# ## Quais estão no primeiro quartil para todas as métricas?

# %%
(df[
    (df.c_v >= df.c_v.quantile(0.75)) &
    (df.u_mass >= df.u_mass.quantile(0.75)) &
    (df.c_npmi >= df.c_npmi.quantile(0.75)) 
]).style.background_gradient(cmap='gray',subset=['n_topics','c_v', 'c_npmi', 'u_mass'])
# Out:
# <style type="text/css">
# #T_cd883_row0_col3, #T_cd883_row1_col4, #T_cd883_row1_col5, #T_cd883_row1_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_cd883_row0_col4 {
#   background-color: #a2a2a2;
#   color: #f1f1f1;
# }
# #T_cd883_row0_col5 {
#   background-color: #0a0a0a;
#   color: #f1f1f1;
# }
# #T_cd883_row0_col6, #T_cd883_row2_col3, #T_cd883_row2_col4, #T_cd883_row2_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_cd883_row1_col3 {
#   background-color: #2a2a2a;
#   color: #f1f1f1;
# }
# #T_cd883_row2_col6 {
#   background-color: #828282;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cd883">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd883_level0_col0" class="col_heading level0 col0" >embedding_model</th>
#       <th id="T_cd883_level0_col1" class="col_heading level0 col1" >n_neighbors</th>
#       <th id="T_cd883_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#       <th id="T_cd883_level0_col3" class="col_heading level0 col3" >n_topics</th>
#       <th id="T_cd883_level0_col4" class="col_heading level0 col4" >c_v</th>
#       <th id="T_cd883_level0_col5" class="col_heading level0 col5" >c_npmi</th>
#       <th id="T_cd883_level0_col6" class="col_heading level0 col6" >u_mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd883_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_cd883_row0_col0" class="data row0 col0" >granite</td>
#       <td id="T_cd883_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_cd883_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_cd883_row0_col3" class="data row0 col3" >24</td>
#       <td id="T_cd883_row0_col4" class="data row0 col4" >0.573339</td>
#       <td id="T_cd883_row0_col5" class="data row0 col5" >0.020438</td>
#       <td id="T_cd883_row0_col6" class="data row0 col6" >-4.170806</td>
#     </tr>
#     <tr>
#       <th id="T_cd883_level0_row1" class="row_heading level0 row1" >17</th>
#       <td id="T_cd883_row1_col0" class="data row1 col0" >paraphrase</td>
#       <td id="T_cd883_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_cd883_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_cd883_row1_col3" class="data row1 col3" >9</td>
#       <td id="T_cd883_row1_col4" class="data row1 col4" >0.590744</td>
#       <td id="T_cd883_row1_col5" class="data row1 col5" >0.050590</td>
#       <td id="T_cd883_row1_col6" class="data row1 col6" >-2.348568</td>
#     </tr>
#     <tr>
#       <th id="T_cd883_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_cd883_row2_col0" class="data row2 col0" >paraphrase</td>
#       <td id="T_cd883_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_cd883_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_cd883_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_cd883_row2_col4" class="data row2 col4" >0.542992</td>
#       <td id="T_cd883_row2_col5" class="data row2 col5" >0.019195</td>
#       <td id="T_cd883_row2_col6" class="data row2 col6" >-3.243216</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Dos clusters com maior número de tópicos, algum se encontra acima do segundo quartil para todas as métricas?

# %%
(df[
    (df.c_v >= df.c_v.quantile(0.5)) &
    (df.u_mass >= df.u_mass.quantile(0.5)) &
    (df.c_npmi >= df.c_npmi.quantile(0.5)) &
    (df.n_topics >= df.n_topics.quantile(0.5))
]).style.background_gradient(cmap='viridis',subset=['n_topics','c_v', 'c_npmi', 'u_mass'])
# Out:
# <style type="text/css">
# #T_56067_row0_col3, #T_56067_row0_col4, #T_56067_row1_col3, #T_56067_row2_col5, #T_56067_row2_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_56067_row0_col5 {
#   background-color: #93d741;
#   color: #000000;
# }
# #T_56067_row0_col6 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_56067_row1_col4, #T_56067_row1_col5, #T_56067_row1_col6, #T_56067_row2_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_56067_row2_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_56067">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56067_level0_col0" class="col_heading level0 col0" >embedding_model</th>
#       <th id="T_56067_level0_col1" class="col_heading level0 col1" >n_neighbors</th>
#       <th id="T_56067_level0_col2" class="col_heading level0 col2" >cluster_size</th>
#       <th id="T_56067_level0_col3" class="col_heading level0 col3" >n_topics</th>
#       <th id="T_56067_level0_col4" class="col_heading level0 col4" >c_v</th>
#       <th id="T_56067_level0_col5" class="col_heading level0 col5" >c_npmi</th>
#       <th id="T_56067_level0_col6" class="col_heading level0 col6" >u_mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56067_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_56067_row0_col0" class="data row0 col0" >granite</td>
#       <td id="T_56067_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_56067_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_56067_row0_col3" class="data row0 col3" >24</td>
#       <td id="T_56067_row0_col4" class="data row0 col4" >0.542433</td>
#       <td id="T_56067_row0_col5" class="data row0 col5" >0.016285</td>
#       <td id="T_56067_row0_col6" class="data row0 col6" >-4.538520</td>
#     </tr>
#     <tr>
#       <th id="T_56067_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_56067_row1_col0" class="data row1 col0" >granite</td>
#       <td id="T_56067_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_56067_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_56067_row1_col3" class="data row1 col3" >24</td>
#       <td id="T_56067_row1_col4" class="data row1 col4" >0.573339</td>
#       <td id="T_56067_row1_col5" class="data row1 col5" >0.020438</td>
#       <td id="T_56067_row1_col6" class="data row1 col6" >-4.170806</td>
#     </tr>
#     <tr>
#       <th id="T_56067_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_56067_row2_col0" class="data row2 col0" >granite</td>
#       <td id="T_56067_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_56067_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_56067_row2_col3" class="data row2 col3" >25</td>
#       <td id="T_56067_row2_col4" class="data row2 col4" >0.547122</td>
#       <td id="T_56067_row2_col5" class="data row2 col5" >-0.004890</td>
#       <td id="T_56067_row2_col6" class="data row2 col6" >-4.659907</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Conclusões
#
# Tendo em vista a análise dos parametros que apresentaram melhor desempenho geral nas métricas e priorizando a maior diversidade de tópicos identificados, destaca-se positivamente a combinação do modelo IBM/Granite com min_cluster_size=10 e n_neighbors=15. Destaca-se também a configuração por se tratar do padrão utilizado de forma automática pela biblioteca.
